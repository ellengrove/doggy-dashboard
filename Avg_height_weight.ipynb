# %%
import pandas as pd

# %%
updated_df = pd.read_csv("static/data/data_for_database.csv")
updated_df
# Out:
#       id   breed_group                         name  weight_lower  \
# 0      1           Toy                Affenpinscher           6.0
# 1      2         Hound                 Afghan Hound          50.0
# 2      3           NaN          African Hunting Dog          44.0
# 3      4       Terrier             Airedale Terrier          40.0
# 4      5       Working                   Akbash Dog          90.0
# ..   ...           ...                          ...           ...
# 167  259           NaN             Wire Fox Terrier          15.0
# 168  260      Sporting  Wirehaired Pointing Griffon          45.0
# 169  261      Sporting            Wirehaired Vizsla          45.0
# 170  262  Non-Sporting               Xoloitzcuintli           9.0
# 171  264           Toy            Yorkshire Terrier           4.0
#
#      weight_upper                                        image_url  \
# 0            13.0  https://cdn2.thedogapi.com/images/BJa4kxc4X.jpg
# ...

# %%
updated_df["avg_height"] = (updated_df['height_lower'] + updated_df['height_upper']) / 2
updated_df["avg_weight"] = (updated_df['weight_lower'] + updated_df['weight_upper']) / 2
updated_df["avg_life"] = (updated_df['life_span_lower'] + updated_df['life_span_upper']) / 2
updated_df
# Out:
#       id   breed_group                         name  weight_lower  \
# 0      1           Toy                Affenpinscher           6.0
# 1      2         Hound                 Afghan Hound          50.0
# 2      3           NaN          African Hunting Dog          44.0
# 3      4       Terrier             Airedale Terrier          40.0
# 4      5       Working                   Akbash Dog          90.0
# ..   ...           ...                          ...           ...
# 167  259           NaN             Wire Fox Terrier          15.0
# 168  260      Sporting  Wirehaired Pointing Griffon          45.0
# 169  261      Sporting            Wirehaired Vizsla          45.0
# 170  262  Non-Sporting               Xoloitzcuintli           9.0
# 171  264           Toy            Yorkshire Terrier           4.0
#
#      weight_upper                                        image_url  \
# 0            13.0  https://cdn2.thedogapi.com/images/BJa4kxc4X.jpg
# ...

# %%
updated_df.to_csv('new_updated.csv')
